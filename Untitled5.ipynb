# %% [markdown]
# <a href="https://colab.research.google.com/github/tleitchColumbia/hw1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""Obj1_ListMethods.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1u1Ymu-b3mB90engF5WNn4hoo1VaiDcog

Lists
Methods: pop, insert, remove, reverse, append, extend
"""

alphabet = ['a','b','c','d']

type(alphabet)

alphabet[-1]

"""Assignment
Create and print the sequence of coupon payments
Retrieve the last payment by using a negative index
Print the payment periods
"""

for a in alphabet:
    print(a)

n = 16
while n >= 1:
    print(n)
    n /= 2

"""Assignment
Write a function that takes n as an argument
print n
Update the value of n by assinging it half its value
Use a while loop to repeat until n == 1
"""

wordlist = ['hi','how','are','you']
sentence = ''
for i in wordlist:
    sentence += i + ' '
sentence

"""Assignment
Use string manipulation to send an email
"""

# List Methods
# sort, append, duplicate, insert, extend

numlist = list([5,3,1])
numlist

numlist.sort()
numlist

numlist.sort(reverse = True)
print(numlist)
numlist.sort(reverse = False)
print(numlist)

numlist.index(5)

numlist.reverse()
numlist

numlist.reverse()
numlist

numlist.append(6)
numlist

numlist.extend([7,9])
numlist

numlist.insert(1,2)
numlist

numlist.insert(3,4)
numlist

numlist.insert(-1,8)
numlist

numlist.clear()
numlist

numlist = list(range(1,6))
numlist

numlist.pop(1)
numlist

numlist.pop(2)

numlist.pop()

numlist

numlist.remove(3)

numlist

alphabet = ['a','b','c','d']

alphabet.index('c')

words = ['fat','cat','sat','mat','sat','mat']
words.count('sat')

' '.join(words)

range(1,4)

list(range(1,4))
# Out:
# 2170604.056735517
