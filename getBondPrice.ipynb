# %% [markdown]
# <a href="https://colab.research.google.com/github/tleitchColumbia/hw1/blob/main/getBondPrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jun 11 21:18:56 2024

@author: tleitch
"""

def getBondPrice(y, face, couponRate, m, ppy=1):
    df=1/(1+y/ppy)
    bondPrice=0
    cpn=couponRate*face/ppy

    return(bondPrice)


# Test values

y = 0.03
face = 2000000
couponRate = 0.04
m = 10
ppy = 1
ppy = 2
#<no ppy value passed>

getBondPrice(y, face, couponRate, m)
# Out:
# 2170604.056735517
